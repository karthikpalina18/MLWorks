# %% [markdown]
# # PRINT

# %%
print("Maniteja Gaddam")
# Out:
# Maniteja Gaddam

# %% [markdown]
# # SUM

# %%
a = 10
b = 12
print(a + b)
# Out:
# 22

# %% [markdown]
# # IF ELSE CONDITION

# %%
n = 10
if n == 10:
  print( " it is 10")
else:
  print("it is not 10")

# %% [markdown]
# # DISPLAYING IMAGE

# %%
from PIL import Image


image = Image.open("1.png")

resized_image = image.resize((256, 256))


display(resized_image)
# Out:
# <PIL.Image.Image image mode=RGBA size=256x256>

# %% [markdown]
# # CREATING DIRECTORY

# %%
mkdir new

# %% [markdown]
# # INSERTING LINK

# %%
link = "https://colab.research.google.com/drive/1zmX7Ne3lMmwOlxkdxQjTGKmU-HYa371Q#scrollTo=iCwb1p2lBsak"

# %% [markdown]
# # INTRODUCTION

# %%
introduction = """
Maniteja Gaddam is a Computer Science and Artificial Intelligence enthusiast with expertise in Python, Machine Learning, Deep Learning, Transformers, and Computer Vision. Proficient in frameworks like Django, Flask, and Streamlit, they excel at integrating AI models into practical applications, blending innovation with user-friendly design.

Maniteja's portfolio includes diverse projects like Agri Mart, a platform connecting farmers with buyers, and Marketing App, which analyzes business reviews for sentiment analysis. They have also developed solutions in areas like movie and house price recommendations, gold price prediction, and chatbot creation using Hugging Face models. Maniteja has actively participated in hackathons, showcasing their ability to craft creative applications.

Technical proficiencies extend to web development (HTML, CSS, JavaScript) with website clones, and contributions on Kaggle for model building in domains such as text summarization and image classification. With a strong foundation and hands-on experience, Maniteja offers innovative problem-solving in AI and development.
"""

# %% [markdown]
# # Hymer mark Text
# - points

# %% [markdown]
# # TABLE

# %%
import numpy as np
import pandas as pd


random_numbers = np.random.randint(0, 101, size=(10, 2))


df = pd.DataFrame(random_numbers, columns=["Column 1", "Column 2"])


print("Table with Random Numbers:")
print(df)


df.to_csv("random_numbers_table.csv", index=False)
# Out:
# Table with Random Numbers:
#    Column 1  Column 2
# 0       100        47
# 1         4        66
# 2        50        48
# 3        54        62
# 4        15        86
# 5        45        83
# 6        76       100
# 7        75        19
# 8        11        83
# 9        47        32
