# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Copy of zomato.csv')

# %%
dataset.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
n=dataset.isnull().sum()
percentage=(n/len(dataset))*100
percentage
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
dataset['menu_item'].unique().sum()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
dataset.shape
# Out:
# (51717, 17)

# %%
dataset.head(5)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
# dataset.dropna(inplace=True)

# %%
# dataset.isnull().sum()

# %%
dataset.shape
# Out:
# (51717, 17)

# %%
sns.countplot(dataset['book_table'])
# Out:
# <Axes: xlabel='count', ylabel='book_table'>

# %%
sns.countplot(dataset['online_order'])
# Out:
# <Axes: xlabel='count', ylabel='online_order'>

# %%
# sns.countplot(dataset['dish_liked'])

# %%
dataset['listed_in(type)'].unique()
# Out:
# array(['Buffet', 'Cafes', 'Delivery', 'Desserts', 'Dine-out',
#        'Drinks & nightlife', 'Pubs and bars'], dtype=object)

# %%
sns.countplot(dataset['listed_in(type)'])
# Out:
# <Axes: xlabel='count', ylabel='listed_in(type)'>

# %%
dataset['rest_type'].unique()
# Out:
# array(['Casual Dining', 'Cafe, Casual Dining', 'Quick Bites',
#        'Casual Dining, Cafe', 'Cafe', 'Quick Bites, Cafe',
#        'Cafe, Quick Bites', 'Delivery', 'Mess', 'Dessert Parlor',
#        'Bakery, Dessert Parlor', 'Pub', 'Bakery', 'Takeaway, Delivery',
#        'Fine Dining', 'Beverage Shop', 'Sweet Shop', 'Bar',
#        'Beverage Shop, Quick Bites', 'Confectionery',
#        'Quick Bites, Beverage Shop', 'Dessert Parlor, Sweet Shop',
#        'Bakery, Quick Bites', 'Sweet Shop, Quick Bites', 'Kiosk',
#        'Food Truck', 'Quick Bites, Dessert Parlor',
#        'Beverage Shop, Dessert Parlor', 'Takeaway', 'Pub, Casual Dining',
#        'Casual Dining, Bar', 'Dessert Parlor, Beverage Shop',
#        'Quick Bites, Bakery', 'Dessert Parlor, Quick Bites',
#        'Microbrewery, Casual Dining', 'Lounge', 'Bar, Casual Dining',
#        'Food Court', 'Cafe, Bakery', nan, 'Dhaba',
#        'Quick Bites, Sweet Shop', 'Microbrewery',
# ...

# %%
x=dataset.dropna()
x.groupby('rate')['name'].apply(lambda x:x.sort_values(ascending=False)).tail(10)
# Out:
# rate
# NEW   17745            Biryani Trip
#       11489              Biergarten
#       11443              Biergarten
#       10868              Biergarten
#       20532           Baba Chatkora
#       10944           Baba Chatkora
#       23164           Baba Chatkora
#       22256           Baba Chatkora
#       14556    46 Ounces Brewgarden
#       14051    46 Ounces Brewgarden
# Name: name, dtype: object

# %% [markdown]
# ---

# %%
val = dataset['name'].value_counts()[:25]
sns.countplot(dataset['name'],order=val.index)
# Out:
# <Axes: xlabel='count', ylabel='name'>

# %%
dataset['rate'].head(5)
# Out:
# 0    4.1/5
# 1    4.1/5
# 2    3.8/5
# 3    3.7/5
# 4    3.8/5
# Name: rate, dtype: object

# %%
dataset['rate']=dataset['rate'].astype(str).apply(lambda x: x.replace("/5",""))

# %%
dataset['rate'].head(5)
# Out:
# 0    4.1
# 1    4.1
# 2    3.8
# 3    3.7
# 4    3.8
# Name: rate, dtype: object

# %%
dataset.rate.unique()
# Out:
# array(['4.1', '3.8', '3.7', '3.6', '4.6', '4.0', '4.2', '3.9', '3.1',
#        '3.0', '3.2', '3.3', '2.8', '4.4', '4.3', 'NEW', '2.9', '3.5',
#        'nan', '2.6', '3.8 ', '3.4', '4.5', '2.5', '2.7', '4.7', '2.4',
#        '2.2', '2.3', '3.4 ', '-', '3.6 ', '4.8', '3.9 ', '4.2 ', '4.0 ',
#        '4.1 ', '3.7 ', '3.1 ', '2.9 ', '3.3 ', '2.8 ', '3.5 ', '2.7 ',
#        '2.5 ', '3.2 ', '2.6 ', '4.5 ', '4.3 ', '4.4 ', '4.9', '2.1',
#        '2.0', '1.8', '4.6 ', '4.9 ', '3.0 ', '4.8 ', '2.3 ', '4.7 ',
#        '2.4 ', '2.1 ', '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
# dataset['rate']=dataset['rate'].astype(str).apply(lambda x: x.replace('NEW','0'))
# dataset['rate'].unique()

dataset.rate=dataset.rate.replace("NEW",np.nan)
dataset.dropna(how='any',inplace=True)

# %%
# dataset['rate']=dataset['rate'].astype(str).apply(lambda x: x.replace('nan','0'))

# dataset['rate']=dataset['rate'].astype(str).apply(lambda x: x.replace('-','0'))
dataset['rate'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '4.6', '4.0', '4.2', '3.9', '3.0', '3.6',
#        '2.8', '4.4', '3.1', '4.3', '2.6', '3.3', '3.5', '3.8 ', '3.2',
#        '4.5', '2.5', '2.9', '3.4', '2.7', '4.7', '2.4', '2.2', '2.3',
#        '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ', '2.9 ', '2.7 ', '2.5 ',
#        '2.6 ', '4.5 ', '4.3 ', '3.7 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '3.4 ', '3.6 ', '3.3 ', '4.6 ', '4.9 ', '3.2 ', '3.0 ', 'nan',
#        '2.8 ', '3.5 ', '3.1 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ',
#        '2.2 ', '2.0 ', '1.8 '], dtype=object)

# %%
dataset.rate=dataset.rate.astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23075 entries, 0 to 51715
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23075 non-null  object
#  1   address                      23075 non-null  object
#  2   name                         23075 non-null  object
#  3   online_order                 23075 non-null  object
#  4   book_table                   23075 non-null  object
#  5   rate                         23046 non-null  float64
#  6   votes                        23075 non-null  int64
#  7   phone                        23075 non-null  object
#  8   location                     23075 non-null  object
#  9   rest_type                    23075 non-null  object
#  10  dish_liked                   23075 non-null  object
#  11  cuisines                     23075 non-null  object
#  12  approx_cost(for two people)  23075 non-null  object
# ...

# %%
dataset.rate.dropna(inplace=True)

# %%
# Rating Distribution

plt.figure(figsize=(12,8))
sns.distplot(dataset['rate'], bins = 25)
# Out:
# <ipython-input-99-5a77166a26fd>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['rate'], bins = 25)
# <Axes: xlabel='rate', ylabel='Density'>

# %%
# Rating Distribution

sns.countplot(dataset['listed_in(type)'])

fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Restaurants delivering online or Not')
# Out:
# Text(0.5, 1.0, 'Restaurants delivering online or Not')

# %%
# !pip install geopandas

# %%
import geopandas as gpd
import folium
from folium.plugins import HeatMap

# %%
import os
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=False)
from geopy.geocoders import Nominatim
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
! pip install dexplot
# Out:
# ...
# WARNING: Ignoring version 0.1.4 of dexplot since it has invalid metadata:
# Requested dexplot from https://files.pythonhosted.org/packages/d6/9a/654a5f873b283f9b77a22087c6fd7762551d3fcd725b8fde36c5a11ba894/dexplot-0.1.4-py3-none-any.whl has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scipy (>=1.0matplotlib>=3.1)
#           ~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
# WARNING: Ignoring version 0.1.3 of dexplot since it has invalid metadata:
# Requested dexplot from https://files.pythonhosted.org/packages/5e/65/69a7f4cf863d162500fc434e4ce2f2d2a2cc2c53e7715db9fb10379329bc/dexplot-0.1.3-py3-none-any.whl has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     scipy (>=1.0matplotlib>=3.1)
#           ~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ...
#   Using cached dexplot-0.1.4-py3-none-any.whl.metadata (32 kB)
# ...

# %%
import dexplot as dxp

# %%
location=dataset['location'].unique()

# %%
dataset.head(10)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
#
#                                               address  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1   2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 3   1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4   10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...

# %%
dataset.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')
