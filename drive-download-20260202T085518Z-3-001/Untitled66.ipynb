# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dat = pd.DataFrame ({
    'roll number': [1, 2, 3, 4],
    'name': ['Alice', 'Bob', 'Charlie', 'David'],
    'marks': [85, 92, 78, 88]
})
dat['percentage'] = ((dat['marks'] / 100) * 100)
display(dat)
# Out:
#    roll number     name  marks  percentage
# 0            1    Alice     85        85.0
# 1            2      Bob     92        92.0
# 2            3  Charlie     78        78.0
# 3            4    David     88        88.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Define parameters
mean = [5, 10]   # Mean vector (μ)
cov = [[2, 0.5],  # Covariance matrix (Σ)
       [0.5, 1]]

# Step 2: Generate random samples
n_samples = 300
data = np.random.multivariate_normal(mean, cov, n_samples)

# Step 3: Convert to DataFrame
df = pd.DataFrame(data, columns=['X1', 'X2'])
print(df.head())

# Step 4: Visualization
plt.figure(figsize=(6, 5))
plt.scatter(df['X1'], df['X2'], c='blue', alpha=0.5, label='Samples')
plt.title('Normal Distribution with Mean & Covariance')
plt.xlabel('Feature X1')
plt.ylabel('Feature X2')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#          X1         X2
# 0  6.255449   9.620400
# 1  5.467215  10.623786
# 2  5.092263  10.922052
# 3  5.899763  10.641182
# 4  8.727458  13.015186
