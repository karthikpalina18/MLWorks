# %%
# !pip install yfinance

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
data = yf.download("GOOGL" , start = "2018-01-01" , interval = '1d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head(3)
# Out:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker          GOOGL      GOOGL      GOOGL      GOOGL      GOOGL     GOOGL
# Date
# 2018-01-02  53.466682  53.660500  53.799000  52.651001  52.651001  31766000
# 2018-01-03  54.378876  54.576000  54.805000  53.671501  53.696499  31318000
# 2018-01-04  54.590103  54.787998  55.203999  54.713001  54.854500  26052000

# %%
# Sort the data points based on indexes just for confirmation
data.sort_index(inplace = True)

# %%
# Remove any duplicate index
data = data.loc[~data.index.duplicated(keep='first')]

# %%
data.tail(3)
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker           GOOGL       GOOGL       GOOGL       GOOGL       GOOGL
# Date
# 2024-12-18  188.399994  188.399994  197.000000  187.740005  195.220001
# 2024-12-19  188.509995  188.509995  193.029999  188.380005  191.630005
# 2024-12-20  191.410004  191.410004  192.889999  185.220001  185.779999
#
# Price         Volume
# Ticker         GOOGL
# Date
# 2024-12-18  34166100
# 2024-12-19  32265200
# 2024-12-20  63326300

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Price      Ticker
# Adj Close  GOOGL     0
# Close      GOOGL     0
# High       GOOGL     0
# Low        GOOGL     0
# Open       GOOGL     0
# Volume     GOOGL     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1755 entries, 2018-01-02 to 2024-12-20
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Adj Close, GOOGL)  1755 non-null   float64
#  1   (Close, GOOGL)      1755 non-null   float64
#  2   (High, GOOGL)       1755 non-null   float64
#  3   (Low, GOOGL)        1755 non-null   float64
#  4   (Open, GOOGL)       1755 non-null   float64
#  5   (Volume, GOOGL)     1755 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 96.0 KB

# %%
# Get the statistics of the data
data.describe()
# Out:
# Price     Adj Close        Close         High          Low         Open  \
# Ticker        GOOGL        GOOGL        GOOGL        GOOGL        GOOGL
# count   1755.000000  1755.000000  1755.000000  1755.000000  1755.000000
# mean     100.929886   101.269777   102.352152   100.145099   101.215817
# std       38.625736    38.717989    39.102246    38.351661    38.716773
# min       49.055672    49.233501    50.605999    48.882999    49.216000
# 25%       61.418354    61.641001    62.241501    61.184000    61.649000
# 50%       99.270142    99.629997   100.930000    97.720001    99.300003
# 75%      134.084686   134.570755   135.741745   133.118004   134.348503
# max      196.660004   196.660004   201.419998   194.979996   197.250000
#
# Price         Volume
# Ticker         GOOGL
# count   1.755000e+03
# mean    3.385881e+07
# std     1.529392e+07
# min     9.312000e+06
# 25%     2.406035e+07
# 50%     3.011400e+07
# 75%     3.847570e+07
# max     1.331780e+08

# %%
# !pip install plotly --upgrade

# %%
import plotly.graph_objects as go

# %%
# import plotly.graph_objects as go
import plotly.io as pio

pio.renderers.default = 'colab'  # Set Colab renderer

# ... (Your code to fetch and prepare the DataFrame) ...

# Accessing the 'Close' values for 'GOOGL'
close_values = data[('Close', 'GOOGL')]

fig = go.Figure()
fig.add_trace(go.Scatter(x=data.index, y=close_values, mode='lines'))
fig.update_layout(height=500, width=900,
                  xaxis_title='Date', yaxis_title='Close')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Check the trend in Closing Values
# fig = go.Figure()

# fig.add_trace(go.Scatter(x = data.index , y = data['Close'] , mode = 'lines'))
# fig.update_layout(height = 500 , width = 900,
#                   xaxis_title='Date' , yaxis_title='Close')
# fig.show()

# %%
import plotly.graph_objects as go
import plotly.io as pio

pio.renderers.default = 'colab'  # Set Colab renderer

# ... (Your code to fetch and prepare the DataFrame) ...

# Accessing the 'Volume' values for 'GOOGL'
volume_values = data[('Volume', 'GOOGL')]

fig = go.Figure()
fig.add_trace(go.Scatter(x=data.index, y=volume_values, mode='lines'))
fig.update_layout(height=500, width=900,
                  xaxis_title='Date', yaxis_title='Volume')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Check the trend in Volume Traded
# fig = go.Figure()

# fig.add_trace(go.Scatter(x = data.index , y = data['Volume'] , mode = 'lines'))
# fig.update_layout(height = 500 , width = 900,
#                   xaxis_title='Date' , yaxis_title='Volume')
# fig.show()

# %%
from sklearn.preprocessing import MinMaxScaler
import pickle
from tqdm.notebook import tnrange

# %%
# Filter only required data
data = data[['Close' , 'Volume']]
data.head(3)
# Out:
# Price           Close    Volume
# Ticker          GOOGL     GOOGL
# Date
# 2018-01-02  53.660500  31766000
# 2018-01-03  54.576000  31318000
# 2018-01-04  54.787998  26052000

# %%
import requests

response = requests.get('https://www.alphavantage.co/query?function=RSI&symbol=GOOGL&interval=daily&time_period=5&series_type=close&apikey=JCKNB4BB5YAZDZJF')
response = response.json()

# %%
response.keys()
# Out:
# dict_keys(['Meta Data', 'Technical Analysis: RSI'])

# %%
rsi_data = pd.DataFrame.from_dict(response['Technical Analysis: RSI'] , orient='index')

# %%
rsi_data.head()
# Out:
#                 RSI
# 2024-12-20  59.4040
# 2024-12-19  51.3298
# 2024-12-18  51.0343
# 2024-12-17  73.9630
# 2024-12-16  78.9771

# %%
rsi_data = rsi_data[rsi_data.index >= '2018-01-01']

# %%
rsi_data['RSI'] = rsi_data['RSI'].astype(np.float64)
# Out:
# <ipython-input-208-7b98dca68617>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rsi_data.head()
# Out:
#                 RSI
# 2024-12-20  59.4040
# 2024-12-19  51.3298
# 2024-12-18  51.0343
# 2024-12-17  73.9630
# 2024-12-16  78.9771

# %%
data = data.droplevel(level=1, axis=1)  # Drop the second level ('GOOGL')
data = data.merge(rsi_data[['RSI']], left_index=True, right_index=True, how='inner', suffixes=('_data', '_rsi'))

# %%
rsi_data.head()
# Out:
#                 RSI
# 2024-12-20  59.4040
# 2024-12-19  51.3298
# 2024-12-18  51.0343
# 2024-12-17  73.9630
# 2024-12-16  78.9771

# %%
# No need to reset the index of rsi_data
# rsi_data = rsi_data.reset_index(level=1, drop=True)  <-- Remove this line

# Drop the unnecessary level from 'data' to match 'rsi_data'
# data = data.droplevel(level=1, axis=1)

# Now perform the merge
data = data.merge(rsi_data[['RSI']], left_index=True, right_index=True, how='inner', suffixes=('_data', '_rsi'))

# %%
data.head(5)
# Out:
# Empty DataFrame
# Columns: [Close, Volume, RSI_data, RSI_rsi]
# Index: []

# %%
# Confirm the Testing Set length
test_length = data[(data.index >= '2020-09-01')].shape[0]

# %%
def CreateFeatures_and_Targets(data, feature_length):
    X = []
    Y = []

    for i in tnrange(len(data) - feature_length):
        X.append(data.iloc[i : i + feature_length,:].values)
        Y.append(data["Close"].values[i+feature_length])

    X = np.array(X)
    Y = np.array(Y)

    return X , Y

# %%
X , Y = CreateFeatures_and_Targets(data , 32)
# Out:
# 0it [00:00, ?it/s]
