# %%
print(f"Hi")
# Out:
# Hi

# %%
a=int(input("Enter num1: "))
b=int(input("Enter num2: "))
print(f"sum is: {a+b}")
# Out:
# Enter num1: 9
# Enter num2: 8
# sum is: 17

# %%
from PIL import Image
from IPython.display import display

# Open an image file
image = Image.open("/content/OIP.jpg")

# Display the image inline
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=149x239>

# %%
a=int(input("Enter num: "))
if(a<10):
  print("single digit")
elif(a<100):
  print("two digit")
elif(a<1000):
  print("three digit")
else:
  print("higher than 999")
# Out:
# Enter num: 4567
# higher than 999

# %%
# prompt: myself karthik i am student persuing 3rd year btech in CSE AI brief me about me in 1000
#  words

# Provided code is not relevant to the task, so it's omitted here.

# A Brief Overview of Karthik, a 3rd Year B.Tech CSE AI Student

Karthik, a third-year B.Tech student specializing in Computer Science and Engineering with a focus on Artificial Intelligence, represents a promising individual within the burgeoning field of AI.  His current academic pursuits provide him with a solid foundation in core computer science principles, augmented by specialized knowledge in the intricacies of AI algorithms, machine learning models, and their practical applications.

**Academic Strengths:**

Karthik's academic journey to this point has likely exposed him to a diverse curriculum encompassing:

* **Programming Fundamentals:**  Proficiency in programming languages such as Python, Java, C++, or others is essential. He likely has experience with data structures, algorithms, and software development methodologies.
* **Mathematics for AI:** A strong mathematical background, encompassing linear algebra, calculus, probability, and statistics, is crucial. These mathematical concepts form the backbone of many AI algorithms.
* **Machine Learning:**  His coursework has likely covered fundamental machine learning algorithms, including supervised learning (regression, classification), unsupervised learning (clustering, dimensionality reduction), and reinforcement learning.  He might be familiar with popular machine learning libraries like TensorFlow, PyTorch, or scikit-learn.
* **Deep Learning:**  A specialization in AI often delves into deep learning architectures like neural networks (CNNs, RNNs, Transformers), potentially exploring applications in computer vision, natural language processing, and other areas.
* **Artificial Intelligence Principles:**  He should have a solid understanding of search algorithms, knowledge representation, reasoning, and planning.
* **Databases:** Database management systems (DBMS) are important for handling large datasets, so he might have experience with SQL or NoSQL databases.

**Potential Skills and Interests:**

Based on his chosen field of study, Karthik might possess or be developing skills in:

* **Python Programming:** Python's prominence in the AI/ML domain suggests a strong likelihood of proficiency in this language.
* **Data Analysis and Visualization:**  Experience in exploring and visualizing datasets using tools like Pandas, NumPy, and Matplotlib is highly probable.
* **Cloud Computing:**  Platforms like AWS, Google Cloud, or Azure might play a significant role in his learning, enabling him to work with large datasets and deploy models.
* **Specific AI Domains:**  He could have specialized interests or developing expertise in areas such as:
    * **Computer Vision:** Image recognition, object detection, image segmentation.
    * **Natural Language Processing (NLP):** Text analysis, machine translation, sentiment analysis, chatbots.
    * **Robotics:**  Controlling robots, path planning, perception.
    * **Data Science:**  Data mining, predictive modeling, business analytics.

**Future Prospects:**

As a third-year student, Karthik is likely at a pivotal stage, exploring internships, research opportunities, and project-based learning. His academic background and developing skills position him well for a variety of career paths in the technology sector, including roles such as:

* **Machine Learning Engineer:** Designing, developing, and deploying machine learning models.
* **Data Scientist:** Analyzing data, extracting insights, and building predictive models.
* **AI Researcher:** Conducting research in novel AI algorithms and techniques.
* **Software Engineer (AI focus):** Developing software applications that utilize AI techniques.
* **Robotics Engineer:** Designing and building intelligent robots.

**Further Development:**

To enhance his skill set further, Karthik could continue building his portfolio through:

* **Personal Projects:**  Developing AI-based projects that showcase his abilities and explore specific areas of interest.
* **Hackathons:** Participating in hackathons provides experience in collaborative problem-solving and rapid prototyping.
* **Internships:** Practical experience within the industry is invaluable.
* **Networking:** Building connections with industry professionals and researchers.
* **Continuous Learning:**  The field of AI is constantly evolving, so ongoing learning is critical.

In conclusion, Karthik, as a third-year B.Tech CSE AI student, has a promising future ahead of him within the exciting and rapidly expanding world of artificial intelligence.  With dedication and further development of his skills, he has the potential to contribute meaningfully to this transformative field.

# %%
from IPython.display import HTML

# Display a clickable link
HTML('<a href="https://www.google.com" target="_blank">Google</a>')
# Out:
# <a href="https://www.google.com" target="_blank">Google</a>

# %%
# Define the timetable
timetable = {
    "Monday": ["Maths", "English", "Physics", "Break", "Computer Science"],
    "Tuesday": ["Chemistry", "Maths", "History", "Break", "English"],
    "Wednesday": ["Biology", "Maths", "Geography", "Break", "Physics"],
    "Thursday": ["Computer Science", "Maths", "Physics", "Break", "Chemistry"],
    "Friday": ["English", "History", "Maths", "Break", "Computer Science"]
}

# Print the timetable
print("Weekly Timetable:")
for day, subjects in timetable.items():
    print(f"{day}: {', '.join(subjects)}")
# Out:
# Weekly Timetable:
# Monday: Maths, English, Physics, Break, Computer Science
# Tuesday: Chemistry, Maths, History, Break, English
# Wednesday: Biology, Maths, Geography, Break, Physics
# Thursday: Computer Science, Maths, Physics, Break, Chemistry
# Friday: English, History, Maths, Break, Computer Science
